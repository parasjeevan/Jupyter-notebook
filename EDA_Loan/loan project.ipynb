# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
loan_data = pd.read_csv(r"J:\@IOT Academy@\Mini_Projects\03_EDA_Loan\loan_sanction.csv")

# %%
loan_data
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents     Education  \
# 0             0  LP001015   Male     Yes          0      Graduate
# 1             1  LP001022   Male     Yes          1      Graduate
# 2             2  LP001031   Male     Yes          2      Graduate
# 3             3  LP001035   Male     Yes          2      Graduate
# 4             4  LP001051   Male      No          0  Not Graduate
# ..          ...       ...    ...     ...        ...           ...
# 362         362  LP002971   Male     Yes         3+  Not Graduate
# 363         363  LP002975   Male     Yes          0      Graduate
# 364         364  LP002980   Male      No          0      Graduate
# 365         365  LP002986   Male     Yes          0      Graduate
# 366         366  LP002989   Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5720                  0         110
# ...

# %%
loan_data.head()
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001015   Male     Yes          0      Graduate            No
# 1           1  LP001022   Male     Yes          1      Graduate            No
# 2           2  LP001031   Male     Yes          2      Graduate            No
# 3           3  LP001035   Male     Yes          2      Graduate            No
# 4           4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0         110               360
# 1             3076               1500         126               360
# 2             5000               1800         208               360
# 3             2340               2546         100               360
# 4             3276                  0          78               360
#
#    Credit_History Property_Area
# 0               1         Urban
# ...

# %%
loan_data.tail()
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents     Education  \
# 362         362  LP002971   Male     Yes         3+  Not Graduate
# 363         363  LP002975   Male     Yes          0      Graduate
# 364         364  LP002980   Male      No          0      Graduate
# 365         365  LP002986   Male     Yes          0      Graduate
# 366         366  LP002989   Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 362           Yes             4009               1777         113
# 363            No             4158                709         115
# 364            No             3250               1993         126
# 365            No             5000               2393         158
# 366           Yes             9200                  0          98
#
#      Loan_Amount_Term  Credit_History Property_Area
# 362               360               1         Urban
# 363               360               1         Urban
# ...

# %%
loan_data.columns
# Out:
# Index(['Unnamed: 0', 'Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
loan_data.shape
# Out:
# (367, 13)

# %% [markdown]
# # 1. Check how many duplicate rows are present

# %%
duplicate_rows = loan_data[loan_data.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %%
Total_duplicate_rows = len(duplicate_rows)
Total_duplicate_rows
print(f"Number of duplicate rows: {Total_duplicate_rows}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# # 2. If any Duplicates Present, drop those duplicates

# %%
duplicate_rows  = duplicate_rows.drop_duplicates(loan_data)
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area]
# Index: []

# %% [markdown]
# # 3. Check null values in each column

# %%
Null_values = loan_data.isnull().sum()
Null_values
# Out:
# Unnamed: 0            0
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           10
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
loan_data = loan_data.shape
loan_data
# Out:
# (367, 13)

# %% [markdown]
# # 4. Delete the Rows which are having null values.

# %%
loan_data = pd.read_csv(r"J:\@IOT Academy@\Mini_Projects\03_EDA_Loan\loan_sanction.csv")
loan_data = loan_data .dropna()
loan_data
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents     Education  \
# 0             0  LP001015   Male     Yes          0      Graduate
# 1             1  LP001022   Male     Yes          1      Graduate
# 2             2  LP001031   Male     Yes          2      Graduate
# 3             3  LP001035   Male     Yes          2      Graduate
# 4             4  LP001051   Male      No          0  Not Graduate
# ..          ...       ...    ...     ...        ...           ...
# 362         362  LP002971   Male     Yes         3+  Not Graduate
# 363         363  LP002975   Male     Yes          0      Graduate
# 364         364  LP002980   Male      No          0      Graduate
# 365         365  LP002986   Male     Yes          0      Graduate
# 366         366  LP002989   Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5720                  0         110
# ...

# %%
Null_values = loan_data.isnull().sum()
Null_values
# Out:
# Unnamed: 0           0
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
loan_data = loan_data.shape   #by giving the command of .shape , you will know the rows are delet which are having null values
loan_data
# Out:
# (357, 13)

# %% [markdown]
# # 5. Impute null values with Mode in Gender Column

# %%
loan_data = pd.read_csv(r"J:\@IOT Academy@\Mini_Projects\03_EDA_Loan\loan_sanction.csv")
# Calculate the mode of the 'Gender' column
gender_mode = loan_data['Gender'].mode()[0]

# Replace null values with the mode
loan_data['Gender'].fillna(gender_mode, inplace=True)

# %%
gender_mode
# Out:
# 'Male'

# %%
print(loan_data['Gender'].isnull().sum())  # Should output 0
# Out:
# 0

# %%
loan_data
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents     Education  \
# 0             0  LP001015   Male     Yes          0      Graduate
# 1             1  LP001022   Male     Yes          1      Graduate
# 2             2  LP001031   Male     Yes          2      Graduate
# 3             3  LP001035   Male     Yes          2      Graduate
# 4             4  LP001051   Male      No          0  Not Graduate
# ..          ...       ...    ...     ...        ...           ...
# 362         362  LP002971   Male     Yes         3+  Not Graduate
# 363         363  LP002975   Male     Yes          0      Graduate
# 364         364  LP002980   Male      No          0      Graduate
# 365         365  LP002986   Male     Yes          0      Graduate
# 366         366  LP002989   Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5720                  0         110
# ...

# %% [markdown]
# # 6. Impute null values with Mode in Self_Employed Column

# %%
selfemployed = loan_data['Self_Employed'].mode()[0]
loan_data['Self_Employed'].fillna(selfemployed, inplace=True)

# %%
selfemployed
# Out:
# 'No'

# %% [markdown]
# # 7. Impute null values with Median in LoanAmount Column

# %%
# Calculate the median of the 'LoanAmount' column
loan_median = loan_data['LoanAmount'].median()

# Replace null values in 'LoanAmount' column with the median
loan_data['LoanAmount'].fillna(loan_median, inplace=True)

# %%
loan_median
# Out:
# 125.0

# %% [markdown]
# # 8. Top 5 Records

# %%
loan_data.head(5)
# Out:
#    Unnamed: 0   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0           0  LP001015   Male     Yes          0      Graduate            No
# 1           1  LP001022   Male     Yes          1      Graduate            No
# 2           2  LP001031   Male     Yes          2      Graduate            No
# 3           3  LP001035   Male     Yes          2      Graduate            No
# 4           4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0         110               360
# 1             3076               1500         126               360
# 2             5000               1800         208               360
# 3             2340               2546         100               360
# 4             3276                  0          78               360
#
#    Credit_History Property_Area
# 0               1         Urban
# ...

# %% [markdown]
# # 9. Export the dataframe in excel.

# %%
# Export the DataFrame to an Excel file
loan_data.to_excel('imputed_data.xlsx', index=False)

# %%
loan_data
# Out:
#      Unnamed: 0   Loan_ID Gender Married Dependents     Education  \
# 0             0  LP001015   Male     Yes          0      Graduate
# 1             1  LP001022   Male     Yes          1      Graduate
# 2             2  LP001031   Male     Yes          2      Graduate
# 3             3  LP001035   Male     Yes          2      Graduate
# 4             4  LP001051   Male      No          0  Not Graduate
# ..          ...       ...    ...     ...        ...           ...
# 362         362  LP002971   Male     Yes         3+  Not Graduate
# 363         363  LP002975   Male     Yes          0      Graduate
# 364         364  LP002980   Male      No          0      Graduate
# 365         365  LP002986   Male     Yes          0      Graduate
# 366         366  LP002989   Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5720                  0         110
# ...

# %% [markdown]
# # 10. Number of Rows and Columns in a DataFrame

# %%
loan_data.shape
# Out:
# (367, 13)

# %%
num_rows, num_columns = loan_data.shape

# %%
num_rows
# Out:
# 367

# %%
num_columns
# Out:
# 13

# %% [markdown]
# # 11. Print all Column names in a DF

# %%
loan_data.columns
# Out:
# Index(['Unnamed: 0', 'Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %% [markdown]
# # 12. Generate the descriptive statistics of Numerical variables.

# %%
# Generate descriptive statistics for numerical variables
numerical_stats = loan_data.describe()
numerical_stats
# Out:
#        Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  367.000000       367.000000         367.000000  367.000000
# mean   183.000000      4805.599455        1569.577657  135.980926
# std    106.088014      4910.685399        2334.232099   60.959739
# min      0.000000         0.000000           0.000000   28.000000
# 25%     91.500000      2864.000000           0.000000  101.000000
# 50%    183.000000      3786.000000        1025.000000  125.000000
# 75%    274.500000      5060.000000        2430.500000  157.500000
# max    366.000000     72529.000000       24000.000000  550.000000
#
#        Loan_Amount_Term  Credit_History
# count        367.000000           367.0
# mean         342.822888             1.0
# std           64.658402             0.0
# min            6.000000             1.0
# 25%          360.000000             1.0
# 50%          360.000000             1.0
# 75%          360.000000             1.0
# max          480.000000             1.0

# %% [markdown]
# # 13. Display numeric data type columns in a DF

# %%
numeric_columns = loan_data.select_dtypes(include=['int64', 'float64'])

print(numeric_columns)
# Out:
#      Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5720                  0         110
# 1             1             3076               1500         126
# 2             2             5000               1800         208
# 3             3             2340               2546         100
# 4             4             3276                  0          78
# ..          ...              ...                ...         ...
# 362         362             4009               1777         113
# 363         363             4158                709         115
# 364         364             3250               1993         126
# 365         365             5000               2393         158
# 366         366             9200                  0          98
#
#      Loan_Amount_Term  Credit_History
# 0                 360               1
# 1                 360               1
# 2                 360               1
# 3                 360               1
# ...

# %% [markdown]
# # 14. Select all data types of columns in a DF except object data type.

# %%
without_object = loan_data.select_dtypes(exclude=['object'])          #without object columns
print(without_object)
# Out:
#      Unnamed: 0  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5720                  0         110
# 1             1             3076               1500         126
# 2             2             5000               1800         208
# 3             3             2340               2546         100
# 4             4             3276                  0          78
# ..          ...              ...                ...         ...
# 362         362             4009               1777         113
# 363         363             4158                709         115
# 364         364             3250               1993         126
# 365         365             5000               2393         158
# 366         366             9200                  0          98
#
#      Loan_Amount_Term  Credit_History
# 0                 360               1
# 1                 360               1
# 2                 360               1
# 3                 360               1
# ...

# %% [markdown]
# # 15. Extract all the Records where Self_Employed is equal to Yes

# %%
# Extract records where 'Self_Employed' is equal to 'Yes'
self_employed_yes = loan_data[loan_data['Self_Employed'] == 'Yes']

print(self_employed_yes)
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 5             5  LP001054    Male     Yes          0  Not Graduate
# 37           37  LP001210    Male     Yes          0      Graduate
# 38           38  LP001211    Male      No          0      Graduate
# 49           49  LP001270    Male     Yes         3+  Not Graduate
# 54           54  LP001312    Male     Yes          0  Not Graduate
# 61           61  LP001335    Male     Yes          0      Graduate
# 73           73  LP001380    Male     Yes          0      Graduate
# 77           77  LP001413    Male      No          0      Graduate
# 90           90  LP001475    Male     Yes          0      Graduate
# 110         110  LP001584  Female      No          0      Graduate
# 132         132  LP001728    Male     Yes          1      Graduate
# 143         143  LP001791    Male     Yes          0      Graduate
# 144         144  LP001794    Male     Yes          2      Graduate
# ...

# %% [markdown]
# # 16. Extract all the Records where Property_area is equal to urban in a DF.

# %%
# Extract records where 'Property_Area' is equal to 'Urban'
urban_records = loan_data[loan_data['Property_Area'] == 'Urban']

print(urban_records)
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 0             0  LP001015    Male     Yes          0      Graduate
# 1             1  LP001022    Male     Yes          1      Graduate
# 2             2  LP001031    Male     Yes          2      Graduate
# 3             3  LP001035    Male     Yes          2      Graduate
# 4             4  LP001051    Male      No          0  Not Graduate
# ..          ...       ...     ...     ...        ...           ...
# 356         356  LP002935    Male     Yes          1      Graduate
# 357         357  LP002952    Male      No          0      Graduate
# 360         360  LP002965  Female     Yes          0      Graduate
# 362         362  LP002971    Male     Yes         3+  Not Graduate
# 363         363  LP002975    Male     Yes          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0              No             5720                  0         110
# ...

# %% [markdown]
# # 17. Print number of unique vaues in Gender column

# %%
# Print the number of unique values in the 'Gender' column
num_unique_gender = loan_data['Gender'].nunique()

print("Number of unique values in the 'Gender' column:", num_unique_gender)
# Out:
# Number of unique values in the 'Gender' column: 2
